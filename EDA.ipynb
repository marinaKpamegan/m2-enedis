# %% [markdown]
# ### EDA

# %%
import os
import pandas as pd

data = pd.read_csv(os.path.join("data_","existents.csv"))
data.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1884\3037156706.py:4: DtypeWarning: Columns (159,191,202,208,214,215,218,219,220,221,228,232) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(os.path.join("data_","existents.csv"))
#    Conso_chauffage_dépensier_é_finale  Volume_stockage_générateur_ECS_n°1  \
# 0                             27974.7                               150.0
# 1                              5399.0                               150.0
# 2                             10570.8                               150.0
# 3                             43968.3                               200.0
# 4                              7775.3                               200.0
#
#    Conso_é_finale_installation_ECS Nom__commune_(BAN)  Emission_GES_chauffage  \
# 0                           2288.3       Saint-Brieuc                  5880.4
# 1                           1916.4       Saint-Brieuc                   319.3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398114 entries, 0 to 398113
# Columns: 235 entries, Conso_chauffage_dépensier_é_finale to Facteur_couverture_solaire_saisi_installation_chauffage_n°1
# dtypes: float64(133), int64(4), object(98)
# memory usage: 713.8+ MB

# %%
# Nombre de variables ayant au moins 20% de valeurs manquantes
(data.isnull().sum() / len(data) > 0.19).value_counts()
# Out:
# False    137
# True      98
# Name: count, dtype: int64

# %%
# Variables qui ont moins de 20% de valeurs manquantes
(data.isnull().sum() / len(data) < 0.2)
# Out:
# Conso_chauffage_dépensier_é_finale                              True
# Volume_stockage_générateur_ECS_n°1                              True
# Conso_é_finale_installation_ECS                                 True
# Nom__commune_(BAN)                                              True
# Emission_GES_chauffage                                          True
#                                                                ...
# Surface_tertiaire_immeuble                                     False
# Facteur_couverture_solaire_installation_chauffage_n°2          False
# Invariant_fiscal_logement                                      False
# Facteur_couverture_solaire_saisi                               False
# Facteur_couverture_solaire_saisi_installation_chauffage_n°1    False
# Length: 235, dtype: bool

# %%
# On récupère seulement ces variables (on en élimine 98 et il en reste 137)
data_cl_1 = data[data.columns[(data.isnull().sum() / len(data) < 0.2)]]

# %%
data_cl_1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398114 entries, 0 to 398113
# Data columns (total 137 columns):
#  #    Column                                                     Dtype
# ---   ------                                                     -----
#  0    Conso_chauffage_dépensier_é_finale                         float64
#  1    Volume_stockage_générateur_ECS_n°1                         float64
#  2    Conso_é_finale_installation_ECS                            float64
#  3    Nom__commune_(BAN)                                         object
#  4    Emission_GES_chauffage                                     float64
#  5    Conso_ECS_é_finale_énergie_n°1                             float64
#  6    Besoin_refroidissement                                     object
#  7    Conso_chauffage_dépensier_installation_chauffage_n°1       float64
#  8    Coût_total_5_usages                                        float64
# ...
